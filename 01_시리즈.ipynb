# %%
import pandas as pd

# %%
dict_data = {
    "a" : 1, 
    "b" : 2,
    "c" : 3,
}

sr = pd.Series(dict_data)

print(sr)
print(type(sr))
# Out:
# a    1
# b    2
# c    3
# dtype: int64
# <class 'pandas.Series'>

# %%
import pandas as pd
list_data = ["2010-01-02", 3.14, "ABC", 100, True]
sr = pd.Series(list_data)
print(type(sr))
print(sr)
# Out:
# <class 'pandas.Series'>
# 0    2010-01-02
# 1          3.14
# 2           ABC
# 3           100
# 4          True
# dtype: object

# %%
print(sr.index)
print(sr.values)
print(sr.dtype)
# Out:
# RangeIndex(start=0, stop=5, step=1)
# ['2010-01-02' 3.14 'ABC' 100 True]
# object

# %%
# 배열의 크기

print(len(sr))
# Out:
# 5

# %%
# shape
sr.shape
# Out:
# (5,)

# %%
# ndim
print(sr.ndim)
# Out:
# 1

# %%
import pandas as pd

tup_data = ("영인", "2010-05-01", "여", True)
sr = pd.Series(tup_data, index= ["이름", "생년월일", "성별", "학생여부"])
print(sr)
# Out:
# 이름              영인
# 생년월일    2010-05-01
# 성별               여
# 학생여부          True
# dtype: object

# %%
# 시리즈의 원소 선택
print(sr["이름"])
# Out:
# 영인

# %%
sr[["생년월일", "성별"]]
# Out:
# 생년월일    2010-05-01
# 성별               여
# dtype: object

# %%
print(sr)
# Out:
# 이름              영인
# 생년월일    2010-05-01
# 성별               여
# 학생여부          True
# dtype: object

# %%
sr["생년월일":"성별"]
# Out:
# 생년월일    2010-05-01
# 성별               여
# dtype: object

# %%
# 빈시리즈
sr = pd.Series()
print(sr)
# Out:
# Series([], dtype: object)

# %%
sr = pd.Series(5)
print(sr)
# Out:
# 0    5
# dtype: int64

# %%
sr = pd.Series(5, index= ["a", "b", "c"])
print(sr)
# Out:
# a    5
# b    5
# c    5
# dtype: int64

# %%
# pandas.DataFrame("2차원배열", 
#                  index = 행 인덱스 배열,
#                  columns = 열 이름 배열
# )

arr = [
    [15, "남", "덕명중"],
    [17, "여", "수리중"]
]

df = pd.DataFrame(arr, index=["준서", "예은"], columns=["나이", "성별", "학교"])

print(df)
# Out:
#     나이 성별   학교
# 준서  15  남  덕명중
# 예은  17  여  수리중

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\KDS-18\AppData\Local\Programs\Python\Python314\python.exe
